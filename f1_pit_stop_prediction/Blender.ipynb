# %%
import pandas as pd
import numpy as np

model_1 = pd.read_csv("submissions\\XGB_LGB_CAT_Submission_V1.csv")
model_2 = pd.read_csv("submissions\\Blended_XGB_LGB_New_FE.csv")

scores = [0.95125, 0.95116] 
models = [model_1, model_2]

blended_probs = scores[0] / sum(scores) * model_1['PitNextLap'] + scores[1] / sum(scores) * model_2['PitNextLap']

blended_probs_df = pd.DataFrame({"id":model_1['id'], "PitNextLap":blended_probs})
blended_probs_df.head()
# Out:
#        id  PitNextLap
# 0  439140    0.011652
# 1  439141    0.015787
# 2  439142    0.010984
# 3  439143    0.368732
# 4  439144    0.939056

# %%
blended_probs_df.to_csv("BLENDED_24_05_2026.csv", index=False)

# %%
# Out:
# Best parameters saved to xgb_params.json
